# %%
import os

# Obtener el directorio actual
directorio_actual = os.getcwd()

print("Directorio actual:", directorio_actual)

# Puedes cambiar el directorio actual utilizando os.chdir()
nuevo_directorio = 'c:/Users/user/Downloads'
os.chdir(nuevo_directorio)

# Verificar el nuevo directorio actual
nuevo_directorio_actual = os.getcwd()
print("Nuevo directorio actual:", nuevo_directorio_actual)
# Out:
# Directorio actual: c:\Users\user\Downloads
# Nuevo directorio actual: c:\Users\user\Downloads

# %%
import pandas as pd
import matplotlib.pyplot as plt

vino = pd.read_csv('vino_categ.csv')
print(vino.head(8))
# Out:
#    acidez fija  acidez volatil  acido citrico  azucar residual calidad
# 0          7.4            0.70           0.00              1.9       M
# 1          7.8            0.88           0.00              2.6       B
# 2          7.8            0.76           0.04              2.3       M
# 3         11.2            0.28           0.56              1.9       P
# 4          7.4            0.70           0.00              1.9       M
# 5          7.4            0.66           0.00              1.8       P
# 6          7.9            0.60           0.06              1.6       M
# 7          7.3            0.65           0.00              1.2       B

# %%
vino.plot(kind='bar')
plt.show()

# %%
vino.groupby('calidad').nunique().plot(kind = 'line')
# Out:
# <Axes: xlabel='calidad'>
